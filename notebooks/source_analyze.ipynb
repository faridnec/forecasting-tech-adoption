# %% [markdown]
# ## Data Analyzation
# Checking raw data obtained from HUPD

# %%
import pandas as pd

# %%
file_path = "../data/hupd_metadata_2022-02-22.feather"

# %%
# Read the head of the data
data = pd.read_feather(file_path)
data
# Out:
#         application_number filing_date application_invention_type  \
# 0                 10018320  2004-06-29                    Utility
# 1                 10018639  2004-03-15                    Utility
# 2                 10048553  2004-10-18                    Utility
# 3                 10048576  2005-03-28                    Utility
# 4                 10049016  2004-06-08                    Utility
# ...                    ...         ...                        ...
# 4518249           16062170  2018-06-14                    Utility
# 4518250           16062262  2018-06-14                    Utility
# 4518251           16062675  2018-06-15                    Utility
# 4518252           16062981  2018-06-15                    Utility
# 4518253           16064534  2018-06-21                    Utility
#
#                examiner_full_name examiner_art_unit uspc_class uspc_subclass  \
# 0        MITCHELL, LAURA MCGILLEM              1636        435        007400
# ...
